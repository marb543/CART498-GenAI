# %% [markdown]
# <a href="https://colab.research.google.com/github/marb543/CART498-GenAI/blob/main/A1/assignment_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch

# Ensure the correct versions of libraries are installed
# !pip install -q diffusers==0.31.0 transformers==4.46.1 tokenizers==0.20.1 scipy ftfy accelerate huggingface-hub==0.26.2

# Check for GPU availability and show GPU details
if torch.cuda.is_available():
    # !nvidia-smi

# Import the necessary library after installation
from diffusers import StableDiffusionPipeline

# Load the pipeline with proper torch settings
pipe = StableDiffusionPipeline.from_pretrained(
    "CompVis/stable-diffusion-v1-4",
    torch_dtype=torch.float16
).to("cuda" if torch.cuda.is_available() else "cpu")

from IPython.display import display

#Write the first surrealist image promt
imagePromt_1 = (
    "A 1950s family barbecque on Venus with aliens with burgers, "
    "in the style of surrealism and abstract expressionism, "
    "neon lighting, detailed scene, hyperrealistic textures "
)

# Generate the first surrealsit image collage from a text prompt
surrealistCollage_1 = pipe(imagePromt_1).images[0]

# Display the first generated image in Colab
display(surrealistCollage_1)

#Save first generated surrealist collage
surrealistCollage_1.save("surreal_collage_1.png")


#Write the second surrealist image promt
imagePromt_2 = (
    "A mid-century atomic family grilling outdoors on Venus with extraterrestrials enjoying burgers, "
    "in a style blending dreamlike surrealism and bold abstract expressionism, "
    "vibrant illumination, accompanied by playful animals ")

# Generate the second surrealsit image collage from a text promt
surrealistCollage_2 = pipe(imagePromt_2).images[0]

# Display the second generated image properly in Colab
display(surrealistCollage_2)

#Save second generated surrealist collage
surrealistCollage_2.save("surreal_collage_2.png")

#Write the second surrealist image promt
imagePromt_3 = (
    "A retro mid-century family cookout on Venus with extraterrestrials enjoying burgers,, "
    "in a style combining fantastical surrealism and dynamic abstract expressionism, "
    "glowing illumination, intricate details, and lifelike textures "
)

# Generate the third surrealsit image collage from a text prompt
surrealistCollage_3 = pipe(imagePromt_3).images[0]

# Display the third generated image properly in Colab
display(surrealistCollage_3)

#Save third generated surrealist collage
surrealistCollage_3.save("surreal_collage_3.png")
# Out:
# Sat Jan 18 21:08:34 2025
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   70C    P0              29W /  70W |   3947MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...
